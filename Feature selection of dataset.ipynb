# %%
import pandas as pd
chunk_data = pd.read_excel("Dataset.xlsx")
corr = chunk_data.corr()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))

# %%
plt.figure(figsize=(24,16))
sns.heatmap(corr, annot=True)
plt.show()

# %%
X = chunk_data.drop("Status",axis=1)
y = chunk_data.Status

# %%
X.shape
# Out:
# (1249, 27)

# %%
y.shape
# Out:
# (1249,)

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = chunk_data.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)# adding this to set so that duplicate entries should not go into the set.
    return col_corr

# %%
corr_features = correlation(X, 0.85)
len(set(corr_features))
# Out:
# 10

# %%
corr_features
# Out:
# {'# total credit transactions for S2',
#  '# total debit transactions for S2',
#  '# total debit transactions for S3',
#  'total credit amount',
#  'total credit amount for S1',
#  'total credit amount for S3',
#  'total credit transactions',
#  'total debit amount',
#  'total debit transactions',
#  'total transactions'}

# %%
# !pip install imbalanced-learn
